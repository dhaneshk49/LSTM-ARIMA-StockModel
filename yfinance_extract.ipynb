# %%
import warnings
warnings.filterwarnings('ignore')
from pathlib import Path
import yfinance as yf
import pandas as pd
from pprint import pprint

# %%
#Loading the Ticker data
tickers = pd.read_csv("/Users/dhaneshkanade/Desktop/stockApp/data/custom_list.csv")

# %%
#View Ticker and Security Name
tickers[['Ticker', 'Company Name']].head()
# Out:
#   Ticker           Company Name
# 0   AAPL             Apple Inc.
# 1   MSFT  Microsoft Corporation
# 2   AMZN            Amazon Inc.
# 3  GOOGL          Alphabet Inc.
# 4   META          Facebook Inc.

# %%
stock_data = yf.Ticker("AAPL")
pprint(stock_data.info)
# Out:
# {'52WeekChange': 0.17896271,
#  'SandP52WeekChange': 0.16350365,
#  'address1': 'One Apple Park Way',
#  'ask': 213.35,
#  'askSize': 100,
#  'auditRisk': 6,
#  'averageDailyVolume10Day': 64166540,
#  'averageVolume': 66541101,
#  'averageVolume10days': 64166540,
#  'beta': 1.244,
#  'bid': 213.25,
#  'bidSize': 100,
#  'boardRisk': 1,
#  'bookValue': 4.382,
#  'city': 'Cupertino',
#  'companyOfficers': [{'age': 62,
#                       'exercisedValue': 0,
#                       'fiscalYear': 2023,
#                       'maxAge': 1,
#                       'name': 'Mr. Timothy D. Cook',
#                       'title': 'CEO & Director',
#                       'totalPay': 16239562,
#                       'unexercisedValue': 0,
#                       'yearBorn': 1961},
#                      {'age': 60,
#                       'exercisedValue': 0,
#                       'fiscalYear': 2023,
#                       'maxAge': 1,
#                       'name': 'Mr. Luca  Maestri',
#                       'title': 'CFO & Senior VP',
#                       'totalPay': 4612242,
#                       'unexercisedValue': 0,
#                       'yearBorn': 1963},
#                      {'age': 59,
#                       'exercisedValue': 0,
#                       'fiscalYear': 2023,
#                       'maxAge': 1,
#                       'name': 'Mr. Jeffrey E. Williams',
#                       'title': 'Chief Operating Officer',
#                       'totalPay': 4637585,
#                       'unexercisedValue': 0,
#                       'yearBorn': 1964},
#                      {'age': 59,
#                       'exercisedValue': 0,
#                       'fiscalYear': 2023,
#                       'maxAge': 1,
#                       'name': 'Ms. Katherine L. Adams',
#                       'title': 'Senior VP, General Counsel & Secretary',
#                       'totalPay': 4618064,
#                       'unexercisedValue': 0,
#                       'yearBorn': 1964},
#                      {'age': 56,
#                       'exercisedValue': 0,
#                       'fiscalYear': 2023,
#                       'maxAge': 1,
#                       'name': "Ms. Deirdre  O'Brien",
#                       'title': 'Senior Vice President of Retail',
#                       'totalPay': 4613369,
#                       'unexercisedValue': 0,
#                       'yearBorn': 1967},
#                      {'exercisedValue': 0,
#                       'fiscalYear': 2023,
#                       'maxAge': 1,
#                       'name': 'Mr. Chris  Kondo',
#                       'title': 'Senior Director of Corporate Accounting',
#                       'unexercisedValue': 0},
#                      {'exercisedValue': 0,
#                       'fiscalYear': 2023,
#                       'maxAge': 1,
#                       'name': 'Mr. James  Wilson',
#                       'title': 'Chief Technology Officer',
#                       'unexercisedValue': 0},
#                      {'exercisedValue': 0,
#                       'fiscalYear': 2023,
#                       'maxAge': 1,
#                       'name': 'Suhasini  Chandramouli',
#                       'title': 'Director of Investor Relations',
#                       'unexercisedValue': 0},
#                      {'exercisedValue': 0,
#                       'fiscalYear': 2023,
#                       'maxAge': 1,
#                       'name': 'Mr. Greg  Joswiak',
#                       'title': 'Senior Vice President of Worldwide Marketing',
#                       'unexercisedValue': 0},
#                      {'age': 49,
#                       'exercisedValue': 0,
#                       'fiscalYear': 2023,
#                       'maxAge': 1,
#                       'name': 'Mr. Adrian  Perica',
#                       'title': 'Head of Corporate Development',
#                       'unexercisedValue': 0,
#                       'yearBorn': 1974}],
#  'compensationAsOfEpochDate': 1703980800,
#  'compensationRisk': 2,
#  'country': 'United States',
#  'currency': 'USD',
#  'currentPrice': 213.31,
#  'currentRatio': 0.953,
#  'dateShortInterest': 1721001600,
#  'dayHigh': 214.2,
#  'dayLow': 208.83,
#  'debtToEquity': 151.862,
#  'dividendRate': 1.0,
#  'dividendYield': 0.0047999998,
#  'earningsGrowth': 0.111,
#  'earningsQuarterlyGrowth': 0.079,
#  'ebitda': 131781001216,
#  'ebitdaMargins': 0.34175,
#  'enterpriseToEbitda': 24.508,
#  'enterpriseToRevenue': 8.376,
#  'enterpriseValue': 3229635051520,
#  'exDividendDate': 1723420800,
#  'exchange': 'NMS',
#  'fiftyDayAverage': 213.7706,
#  'fiftyTwoWeekHigh': 237.23,
#  'fiftyTwoWeekLow': 164.08,
#  'financialCurrency': 'USD',
#  'firstTradeDateEpochUtc': 345479400,
#  'fiveYearAvgDividendYield': 0.68,
#  'floatShares': 15179354257,
#  'forwardEps': 7.48,
#  'forwardPE': 28.51738,
#  'freeCashflow': 86158123008,
#  'fullTimeEmployees': 161000,
#  'gmtOffSetMilliseconds': -14400000,
#  'governanceEpochDate': 1722470400,
#  'grossMargins': 0.45962003,
#  'heldPercentInsiders': 0.05264,
#  'heldPercentInstitutions': 0.58261,
#  'impliedSharesOutstanding': 15410899968,
#  'industry': 'Consumer Electronics',
#  'industryDisp': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'irWebsite': 'http://investor.apple.com/',
#  'lastDividendDate': 1715299200,
#  'lastDividendValue': 0.25,
#  'lastFiscalYearEnd': 1696032000,
#  'lastSplitDate': 1598832000,
#  'lastSplitFactor': '4:1',
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets '
#                         'smartphones, personal computers, tablets, wearables, '
#                         'and accessories worldwide. The company offers iPhone, '
#                         'a line of smartphones; Mac, a line of personal '
#                         'computers; iPad, a line of multi-purpose tablets; and '
#                         'wearables, home, and accessories comprising AirPods, '
#                         'Apple TV, Apple Watch, Beats products, and HomePod. '
#                         'It also provides AppleCare support and cloud '
#                         'services; and operates various platforms, including '
#                         'the App Store that allow customers to discover and '
#                         'download applications and digital content, such as '
#                         'books, music, video, games, and podcasts. In '
#                         'addition, the company offers various services, such '
#                         'as Apple Arcade, a game subscription service; Apple '
#                         'Fitness+, a personalized fitness service; Apple '
#                         'Music, which offers users a curated listening '
#                         'experience with on-demand radio stations; Apple '
#                         'News+, a subscription news and magazine service; '
#                         'Apple TV+, which offers exclusive original content; '
#                         'Apple Card, a co-branded credit card; and Apple Pay, '
#                         'a cashless payment service, as well as licenses its '
#                         'intellectual property. The company serves consumers, '
#                         'and small and mid-sized businesses; and the '
#                         'education, enterprise, and government markets. It '
#                         'distributes third-party applications for its products '
#                         'through the App Store. The company also sells its '
#                         'products through its retail and online stores, and '
#                         'direct sales force; and third-party cellular network '
#                         'carriers, wholesalers, retailers, and resellers. '
#                         'Apple Inc. was founded in 1976 and is headquartered '
#                         'in Cupertino, California.',
#  'longName': 'Apple Inc.',
#  'marketCap': 3243186585600,
#  'maxAge': 86400,
#  'messageBoardId': 'finmb_24937',
#  'mostRecentQuarter': 1719619200,
#  'netIncomeToCommon': 101956001792,
#  'nextFiscalYearEnd': 1727654400,
#  'numberOfAnalystOpinions': 37,
#  'open': 213.095,
#  'operatingCashflow': 113040998400,
#  'operatingMargins': 0.29556,
#  'overallRisk': 1,
#  'payoutRatio': 0.1476,
#  'pegRatio': 2.82,
#  'phone': '408 996 1010',
#  'previousClose': 209.82,
#  'priceHint': 2,
#  'priceToBook': 48.678684,
#  'priceToSalesTrailing12Months': 8.410688,
#  'profitMargins': 0.26441,
#  'quickRatio': 0.798,
#  'quoteType': 'EQUITY',
#  'recommendationKey': 'buy',
#  'recommendationMean': 2.0,
#  'regularMarketDayHigh': 214.2,
#  'regularMarketDayLow': 208.83,
#  'regularMarketOpen': 213.095,
#  'regularMarketPreviousClose': 209.82,
#  'regularMarketVolume': 44537549,
#  'returnOnAssets': 0.22612,
#  'returnOnEquity': 1.60583,
#  'revenueGrowth': 0.049,
#  'revenuePerShare': 24.957,
#  'sector': 'Technology',
#  'sectorDisp': 'Technology',
#  'sectorKey': 'technology',
#  'shareHolderRightsRisk': 1,
#  'sharesOutstanding': 15204100096,
#  'sharesPercentSharesOut': 0.0089,
#  'sharesShort': 135383184,
#  'sharesShortPreviousMonthDate': 1718323200,
#  'sharesShortPriorMonth': 153405579,
#  'shortName': 'Apple Inc.',
#  'shortPercentOfFloat': 0.0089,
#  'shortRatio': 1.83,
#  'state': 'CA',
#  'symbol': 'AAPL',
#  'targetHighPrice': 300.0,
#  'targetLowPrice': 183.86,
#  'targetMeanPrice': 235.07,
#  'targetMedianPrice': 240.0,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EDT',
#  'totalCash': 61801000960,
#  'totalCashPerShare': 4.065,
#  'totalDebt': 101304000512,
#  'totalRevenue': 385603010560,
#  'trailingAnnualDividendRate': 0.97,
#  'trailingAnnualDividendYield': 0.0046230103,
#  'trailingEps': 6.57,
#  'trailingPE': 32.467274,
#  'trailingPegRatio': 2.0653,
#  'twoHundredDayAverage': 190.0109,
#  'underlyingSymbol': 'AAPL',
#  'uuid': '8b10e4ae-9eeb-3684-921a-9ab27e4d87aa',
#  'volume': 44537549,
#  'website': 'https://www.apple.com',
#  'zip': '95014'}

# %%
#Extract for the Entire List
stock_data_info = stock_data.info

# Extract only the important information
stock_data_info = {
    'Basic Information': {
        'businessSummary': stock_data_info['longBusinessSummary'],
        'symbol': stock_data_info['symbol'],
        'longName': stock_data_info['longName'],
        'currency': stock_data_info['currency'],
        'exchange': stock_data_info['exchange']
    },
    'Market Data': {
        'currentPrice': stock_data_info['currentPrice'],
        'previousClose': stock_data_info['previousClose'],
        'open': stock_data_info['open'],
        'dayLow': stock_data_info['dayLow'],
        'dayHigh': stock_data_info['dayHigh'],
        'regularMarketPreviousClose': stock_data_info['regularMarketPreviousClose'],
        'regularMarketOpen': stock_data_info['regularMarketOpen'],
        'regularMarketDayLow': stock_data_info['regularMarketDayLow'],
        'regularMarketDayHigh': stock_data_info['regularMarketDayHigh'],
        'fiftyTwoWeekLow': stock_data_info['fiftyTwoWeekLow'],
        'fiftyTwoWeekHigh': stock_data_info['fiftyTwoWeekHigh'],
        'fiftyDayAverage': stock_data_info['fiftyDayAverage'],
        'twoHundredDayAverage': stock_data_info['twoHundredDayAverage']
    },
    'Volume and Shares': {
        'volume': stock_data_info['volume'],
        'regularMarketVolume': stock_data_info['regularMarketVolume'],
        'averageVolume': stock_data_info['averageVolume'],
        'averageVolume10days': stock_data_info['averageVolume10days'],
        'averageDailyVolume10Day': stock_data_info['averageDailyVolume10Day'],
        'sharesOutstanding': stock_data_info['sharesOutstanding'],
        'impliedSharesOutstanding': stock_data_info['impliedSharesOutstanding'],
        'floatShares': stock_data_info['floatShares']
    },
    'Dividends and Yield': {
        'dividendRate': stock_data_info['dividendRate'],
        'dividendYield': stock_data_info['dividendYield'],
        'payoutRatio': stock_data_info['payoutRatio']
    },
    'Valuation and Ratios': {
        'marketCap': stock_data_info['marketCap'],
        'enterpriseValue': stock_data_info['enterpriseValue'],
        'priceToBook': stock_data_info['priceToBook'],
        'debtToEquity': stock_data_info['debtToEquity'],
        'grossMargins': stock_data_info['grossMargins'],
        'profitMargins': stock_data_info['profitMargins']
    },
    'Financial Performance': {
        'totalRevenue': stock_data_info['totalRevenue'],
        'revenuePerShare': stock_data_info['revenuePerShare'],
        'totalCash': stock_data_info['totalCash'],
        'totalCashPerShare': stock_data_info['totalCashPerShare'],
        'totalDebt': stock_data_info['totalDebt'],
        'earningsGrowth': stock_data_info['earningsGrowth'],
        'revenueGrowth': stock_data_info['revenueGrowth'],
        'returnOnAssets': stock_data_info['returnOnAssets'],
        'returnOnEquity': stock_data_info['returnOnEquity']
    },
    'Cash Flow': {
        'freeCashflow': stock_data_info['freeCashflow'],
        'operatingCashflow': stock_data_info['operatingCashflow']
    },
    'Analyst Targets': {
        'targetHighPrice': stock_data_info['targetHighPrice'],
        'targetLowPrice': stock_data_info['targetLowPrice'],
        'targetMeanPrice': stock_data_info['targetMeanPrice'],
        'targetMedianPrice': stock_data_info['targetMedianPrice']
    }
}

# %%
# View the stock info
pprint(stock_data_info)
# Out:
# {'Analyst Targets': {'targetHighPrice': 300.0,
#                      'targetLowPrice': 183.86,
#                      'targetMeanPrice': 235.07,
#                      'targetMedianPrice': 240.0},
#  'Basic Information': {'businessSummary': 'Apple Inc. designs, manufactures, '
#                                           'and markets smartphones, personal '
#                                           'computers, tablets, wearables, and '
#                                           'accessories worldwide. The company '
#                                           'offers iPhone, a line of '
#                                           'smartphones; Mac, a line of '
#                                           'personal computers; iPad, a line of '
#                                           'multi-purpose tablets; and '
#                                           'wearables, home, and accessories '
#                                           'comprising AirPods, Apple TV, Apple '
#                                           'Watch, Beats products, and HomePod. '
#                                           'It also provides AppleCare support '
#                                           'and cloud services; and operates '
#                                           'various platforms, including the '
#                                           'App Store that allow customers to '
#                                           'discover and download applications '
#                                           'and digital content, such as books, '
#                                           'music, video, games, and podcasts. '
#                                           'In addition, the company offers '
#                                           'various services, such as Apple '
#                                           'Arcade, a game subscription '
#                                           'service; Apple Fitness+, a '
#                                           'personalized fitness service; Apple '
#                                           'Music, which offers users a curated '
#                                           'listening experience with on-demand '
#                                           'radio stations; Apple News+, a '
#                                           'subscription news and magazine '
#                                           'service; Apple TV+, which offers '
#                                           'exclusive original content; Apple '
#                                           'Card, a co-branded credit card; and '
#                                           'Apple Pay, a cashless payment '
#                                           'service, as well as licenses its '
#                                           'intellectual property. The company '
#                                           'serves consumers, and small and '
#                                           'mid-sized businesses; and the '
#                                           'education, enterprise, and '
#                                           'government markets. It distributes '
#                                           'third-party applications for its '
#                                           'products through the App Store. The '
#                                           'company also sells its products '
#                                           'through its retail and online '
#                                           'stores, and direct sales force; and '
#                                           'third-party cellular network '
#                                           'carriers, wholesalers, retailers, '
#                                           'and resellers. Apple Inc. was '
#                                           'founded in 1976 and is '
#                                           'headquartered in Cupertino, '
#                                           'California.',
#                        'currency': 'USD',
#                        'exchange': 'NMS',
#                        'longName': 'Apple Inc.',
#                        'symbol': 'AAPL'},
#  'Cash Flow': {'freeCashflow': 86158123008, 'operatingCashflow': 113040998400},
#  'Dividends and Yield': {'dividendRate': 1.0,
#                          'dividendYield': 0.0047999998,
#                          'payoutRatio': 0.1476},
#  'Financial Performance': {'earningsGrowth': 0.111,
#                            'returnOnAssets': 0.22612,
#                            'returnOnEquity': 1.60583,
#                            'revenueGrowth': 0.049,
#                            'revenuePerShare': 24.957,
#                            'totalCash': 61801000960,
#                            'totalCashPerShare': 4.065,
#                            'totalDebt': 101304000512,
#                            'totalRevenue': 385603010560},
#  'Market Data': {'currentPrice': 213.31,
#                  'dayHigh': 214.2,
#                  'dayLow': 208.83,
#                  'fiftyDayAverage': 213.7706,
#                  'fiftyTwoWeekHigh': 237.23,
#                  'fiftyTwoWeekLow': 164.08,
#                  'open': 213.095,
#                  'previousClose': 209.82,
#                  'regularMarketDayHigh': 214.2,
#                  'regularMarketDayLow': 208.83,
#                  'regularMarketOpen': 213.095,
#                  'regularMarketPreviousClose': 209.82,
#                  'twoHundredDayAverage': 190.0109},
#  'Valuation and Ratios': {'debtToEquity': 151.862,
#                           'enterpriseValue': 3229635051520,
#                           'grossMargins': 0.45962003,
#                           'marketCap': 3243186585600,
#                           'priceToBook': 48.678684,
#                           'profitMargins': 0.26441},
#  'Volume and Shares': {'averageDailyVolume10Day': 64166540,
#                        'averageVolume': 66541101,
#                        'averageVolume10days': 64166540,
#                        'floatShares': 15179354257,
#                        'impliedSharesOutstanding': 15410899968,
#                        'regularMarketVolume': 44537549,
#                        'sharesOutstanding': 15204100096,
#                        'volume': 44537549}}

# %%
# Create dictionary for periods and intervals
periods = {
    '1d': ['1m', '2m', '5m', '15m', '30m', '60m', '90m'],
    '5d': ['1m', '2m', '5m', '15m', '30m', '60m', '90m'],
    '1mo': ['30m', '60m', '90m', '1d'],
    '3mo': ['1d', '5d', '1wk', '1mo'],
    '6mo': ['1d', '5d', '1wk', '1mo'],
    '1y': ['1d', '5d', '1wk', '1mo'],
    '2y': ['1d', '5d', '1wk', '1mo'],
    '5y': ['1d', '5d', '1wk', '1mo'],
    '10y': ['1d', '5d', '1wk', '1mo'],
    'max': ['1d', '5d', '1wk', '1mo'],
}

# %%
# Extract the data for last 1yr with 1d interval
stock_data_hist = stock_data.history(period="2y", interval="1d")
stock_data_hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2022-08-09 00:00:00-04:00  162.410382  164.192721  161.647935  163.301544
# 2022-08-10 00:00:00-04:00  166.034459  167.678172  165.262115  167.579163
# 2022-08-11 00:00:00-04:00  168.391087  169.311968  166.539443  166.836502
# 2022-08-12 00:00:00-04:00  168.153448  170.480377  167.737557  170.411072
# 2022-08-15 00:00:00-04:00  169.836777  171.688421  169.668448  171.490387
# ...                               ...         ...         ...         ...
# 2024-08-02 00:00:00-04:00  219.149994  225.600006  217.710007  219.860001
# 2024-08-05 00:00:00-04:00  199.089996  213.500000  196.000000  209.270004
# 2024-08-06 00:00:00-04:00  205.300003  209.990005  201.070007  207.229996
# 2024-08-07 00:00:00-04:00  206.899994  213.639999  206.389999  209.820007
# 2024-08-08 00:00:00-04:00  213.095001  214.199997  208.830002  213.309998
#
#                               Volume  Dividends  Stock Splits
# Date
# 2022-08-09 00:00:00-04:00   63135500        0.0           0.0
# 2022-08-10 00:00:00-04:00   70170500        0.0           0.0
# 2022-08-11 00:00:00-04:00   57149200        0.0           0.0
# 2022-08-12 00:00:00-04:00   68039400        0.0           0.0
# 2022-08-15 00:00:00-04:00   54091700        0.0           0.0
# ...                              ...        ...           ...
# 2024-08-02 00:00:00-04:00  105568600        0.0           0.0
# 2024-08-05 00:00:00-04:00  119548600        0.0           0.0
# 2024-08-06 00:00:00-04:00   69660500        0.0           0.0
# 2024-08-07 00:00:00-04:00   63516400        0.0           0.0
# 2024-08-08 00:00:00-04:00   44537549        0.0           0.0
#
# [503 rows x 7 columns]

# %%
# Clean the data for to keep only the required columns
stock_data_hist = stock_data_hist[['Close']]

# %%
# Imports
import datetime as dt

#Statsmodels is a great library we can use to run regressions
import statsmodels.api as sm

# Import matplotlib for plotting
import matplotlib.pyplot as plt

# Seaborn extends the capabilities of Matplotlib
import seaborn as sns
sns.set_style("darkgrid")

# %%
# Change frequency to day
stock_data_hist = stock_data_hist.asfreq('D', method='ffill')

# %%
# Fill missing values
stock_data_hist = stock_data_hist.fillna(method='ffill')
# View the new data
stock_data_hist
# Out:
#                                 Close
# Date
# 2022-08-09 00:00:00-04:00  163.301544
# 2022-08-10 00:00:00-04:00  167.579163
# 2022-08-11 00:00:00-04:00  166.836502
# 2022-08-12 00:00:00-04:00  170.411072
# 2022-08-13 00:00:00-04:00  170.411072
# ...                               ...
# 2024-08-04 00:00:00-04:00  219.860001
# 2024-08-05 00:00:00-04:00  209.270004
# 2024-08-06 00:00:00-04:00  207.229996
# 2024-08-07 00:00:00-04:00  209.820007
# 2024-08-08 00:00:00-04:00  213.309998
#
# [731 rows x 1 columns]
